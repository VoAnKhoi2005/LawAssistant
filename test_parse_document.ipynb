# %%
from pprint import pprint
from pathlib import Path
import pandas as pd
from triplet_extraction.src.doc_extraction.parse_text_to_section import parse_document

TARGET_SO_HIEU = "96/2024/NĐ-CP"

data_folder = Path(r"E:\Github\LawAssistant\triplet_extraction\data\luat_dat_dai")
extracted_csv = data_folder / "extracted_texts_google.csv"
df = pd.read_csv(extracted_csv, encoding='utf-8-sig')
print(f"Loaded {len(df)} documents from CSV")

row = df.loc[df["so_hieu"] == TARGET_SO_HIEU]

if row.empty:
    print("Document not found")
else:
    r = row.iloc[0]
    result = parse_document(r["combined_text"], r["so_hieu"])
    for k, v in list(result.items())[:100]:
        pprint(v)
# Out:
# Loaded 62 documents from CSV
# {'content': 'QUY ĐỊNH CHUNG',
#  'full_path': '96/2024/NĐ-CP_chương i',
#  'id': ObjectId('694fb65cf9f7062ab1a6b29b'),
#  'is_amendment': False,
#  'parent_id': None,
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'chương i',
#  'type': 'chương'}
# {'content': 'phạm vi điều chỉnh Nghị định này quy định chi tiết một số điều '
#             'của Luật Kinh doanh bất động sản ngày 28 tháng 11 năm 2023 (sau '
#             'đây gọi tắt là Luật Kinh doanh bất động sản), gồm:',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29b'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 1',
#  'type': 'điều'}
# {'content': 'Khoản 2, khoản 3 Điều 5 về công trình xây dựng có công năng phục '
#             'vụ mục đích giáo dục, y tế, thể thao, văn hóa, văn phòng, thương '
#             'mại, dịch vụ, du lịch, lưu trú, công nghiệp và công trình xây '
#             'dựng có công năng phục vụ hỗn hợp; về phần diện tích sàn xây dựng '
#             'trong công trình xây dựng. CÔNG BÁO/Số 937 + 938/Ngày 16-8-2024 3',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b29d'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Điều 6 về công khai thông tin về bất động sản, dự án bất động sản '
#             'đưa vào kinh doanh.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b29e'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'Điểm b, điểm c khoản 2, khoản 3 và khoản 4 Điều 9 về tỷ lệ dư nợ '
#             'tín dụng, dư nợ trái phiếu doanh nghiệp trên số vốn chủ sở hữu '
#             'của doanh nghiệp kinh doanh bất động sản; vốn chủ sở hữu của '
#             'doanh nghiệp kinh doanh bất động sản; kinh doanh bất động sản quy '
#             'mô nhỏ.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 3',
#  'id': ObjectId('694fb65cf9f7062ab1a6b29f'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 3',
#  'type': 'khoản'}
# {'content': 'Khoản 4 Điều 24 về việc thông báo cho cơ quan quản lý nhà nước về '
#             'kinh doanh bất động sản cấp tỉnh nhà ở đủ điều kiện được bán, cho '
#             'thuê mua của chủ đầu tư dự án.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 4',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a0'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 4',
#  'type': 'khoản'}
# {'content': 'Khoản 7 Điều 31 về việc thông báo cho cơ quan quản lý nhà nước về '
#             'kinh doanh bất động sản cấp tỉnh quyền sử dụng đất đã có hạ tầng '
#             'kỹ thuật trong dự án bất động sản đủ điều kiện được chuyển nhượng '
#             'của chủ đầu tư dự án.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 5',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a1'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 5',
#  'type': 'khoản'}
# {'content': 'Điều 42 về thủ tục chuyển nhượng toàn bộ hoặc một phần dự án bất '
#             'động sản.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 6',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a2'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 6',
#  'type': 'khoản'}
# {'content': 'Khoản 1 Điều 44 về các loại hợp đồng mẫu trong kinh doanh bất '
#             'động sản.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 7',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a3'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 7',
#  'type': 'khoản'}
# {'content': 'Điều 52 về trình tự, thủ tục, hồ sơ chuyển nhượng hợp đồng kinh '
#             'doanh bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 8',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a4'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 8',
#  'type': 'khoản'}
# {'content': 'Khoản 3 Điều 54 về sàn giao dịch bất động sản trước khi hoạt động '
#             'phải gửi hồ sơ đến cơ quan quản lý nhà nước về kinh doanh bất '
#             'động sản cấp tỉnh nơi có trụ sở chính của sàn giao dịch bất động '
#             'sản để được cấp giấy phép hoạt động.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 9',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a5'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 9',
#  'type': 'khoản'}
# {'content': 'Điều 55 về điều kiện hoạt động của sàn giao dịch bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 10',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a6'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 10',
#  'type': 'khoản'}
# {'content': 'Điều 56 về nội dung hoạt động của sàn giao dịch bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 11',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a7'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 11',
#  'type': 'khoản'}
# {'content': 'Điều 60 về quản lý hoạt động của sàn giao dịch bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 12',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a8'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 12',
#  'type': 'khoản'}
# {'content': 'Điểm b khoản 1 Điều 61 về cơ sở vật chất, kỹ thuật tổ chức, cá '
#             'nhân kinh doanh dịch vụ môi giới bất động sản phải đáp ứng.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 13',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2a9'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 13',
#  'type': 'khoản'}
# {'content': 'Khoản 3 Điều 70 về tổ chức kỳ thi sát hạch và cấp chứng chỉ hành '
#             'nghề môi giới bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 14',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2aa'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 14',
#  'type': 'khoản'}
# {'content': 'Khoản 1 Điều 79 về việc Bộ Xây dựng chủ trì, phối hợp với các bộ, '
#             'cơ quan ngang bộ, Ủy ban nhân dân cấp tỉnh nghiên cứu, đề xuất '
#             'các biện pháp điều tiết thị trường bất động sản quy định tại Điều '
#             '78 của Luật Kinh doanh bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 15',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ab'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 15',
#  'type': 'khoản'}
# {'content': 'Tổ chức nước ngoài, cá nhân nước ngoài, người Việt Nam định cư ở '
#             'nước ngoài mà không phải là công dân Việt Nam được thuê nhà ở '
#             'theo quy định của pháp luật về nhà ở. 4 CÔNG BÁO/Số 937 + '
#             '938/Ngày 16-8-2024',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 1_khoản 16',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ac'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29c'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 16',
#  'type': 'khoản'}
# {'content': 'đối tượng áp dụng',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ad'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b29b'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 2',
#  'type': 'điều'}
# {'content': 'Tổ chức, cá nhân kinh doanh bất động sản tại Việt Nam.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 2_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ae'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2ad'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Cơ quan, tổ chức, cá nhân liên quan đến kinh doanh bất động sản '
#             'tại Việt Nam.',
#  'full_path': '96/2024/NĐ-CP_chương i_điều 2_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2af'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2ad'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'KINH DOANH BẤT ĐỘNG SẢN CÓ SẴN VÀ KINH DOANH BẤT ĐỘNG SẢN HÌNH '
#             'THÀNH TRONG TƯƠNG LAI',
#  'full_path': '96/2024/NĐ-CP_chương ii',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b0'),
#  'is_amendment': False,
#  'parent_id': None,
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'chương ii',
#  'type': 'chương'}
# {'content': 'các loại công trình xây dựng, phần diện tích sàn xây dựng trong '
#             'công trình xây dựng đưa vào kinh doanh',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 3',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b1'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 3',
#  'type': 'điều'}
# {'content': 'Công trình xây dựng có sẵn, công trình xây dựng hình thành trong '
#             'tương lai đưa vào kinh doanh quy định tại khoản 2 Điều 5 Luật '
#             'Kinh doanh bất động sản được phân loại theo quy định của pháp '
#             'luật về xây dựng.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 3_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b2'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b1'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Phần diện tích sàn xây dựng trong công trình xây dựng đưa vào '
#             'kinh doanh bao gồm:',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 3_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b3'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b1'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'Diện tích sàn xây dựng có công năng phục vụ mục đích thương mại, '
#             'gồm: gian thương mại, lô thương mại và các phần diện tích sàn xây '
#             'dựng có công năng phục vụ mục đích thương mại có tên gọi khác;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 3_khoản 2_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b4'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b3'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Diện tích sàn xây dựng có công năng phục vụ mục đích văn phòng, '
#             'gồm: văn phòng làm việc, văn phòng kết hợp lưu trú và các phần '
#             'diện tích sàn xây dựng có công năng phục vụ mục đích văn phòng có '
#             'tên gọi khác;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 3_khoản 2_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b5'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b3'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Diện tích sàn xây dựng có công năng phục vụ mục đích du lịch, lưu '
#             'trú, gồm: căn hộ du lịch, căn hộ lưu trú và các phần diện tích '
#             'sàn xây dựng có công năng phục vụ mục đích du lịch, lưu trú có '
#             'tên gọi khác;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 3_khoản 2_điểm c',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b6'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b3'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm c',
#  'type': 'điểm'}
# {'content': 'Diện tích sàn xây dựng có công năng phục vụ mục đích hỗn hợp và '
#             'diện tích sàn xây dựng có công năng phục vụ mục đích khác trong '
#             'công trình xây dựng quy định tại khoản 2 Điều 5 Luật Kinh doanh '
#             'bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 3_khoản 2_điểm d',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b7'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b3'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm d',
#  'type': 'điểm'}
# {'content': 'công khai thông tin về bất động sản, dự án bất động sản đưa vào '
#             'kinh doanh',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b8'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 4',
#  'type': 'điều'}
# {'content': 'Thời điểm công khai thông tin: Doanh nghiệp kinh doanh bất động '
#             'sản trước khi ký kết hợp đồng bán, chuyển nhượng, cho thuê, cho '
#             'thuê mua bất động sản, chuyển nhượng dự án bất động sản có trách '
#             'nhiệm phải công khai đầy đủ các thông tin theo quy định tại Điều '
#             '6 Luật Kinh doanh bất động sản. CÔNG BÁO/Số 937 + 938/Ngày '
#             '16-8-2024 5',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2b9'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b8'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Nội dung thông tin công khai thực hiện theo quy định tại khoản 2, '
#             'khoản 3, khoản 4 và khoản 5 Điều 6 Luật Kinh doanh bất động sản; '
#             'thông tin tại điểm c khoản 2 và điểm b, d khoản 3 Điều 6 Luật '
#             'Kinh doanh bất động sản là các tài liệu sau:',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ba'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b8'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'Quyết định phê duyệt quy hoạch chi tiết hoặc quyết định phê duyệt '
#             'quy hoạch tổng mặt bằng của dự án bất động sản của cơ quan nhà '
#             'nước có thẩm quyền theo quy định của pháp luật về xây dựng, về '
#             'quy hoạch đô thị;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4_khoản 2_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2bb'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2ba'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Thông báo kết quả thẩm định báo cáo nghiên cứu khả thi đầu tư xây '
#             'dựng hoặc Thông báo kết quả thẩm định thiết kế cơ sở của cơ quan '
#             'nhà nước có thẩm quyền theo quy định của pháp luật về xây dựng;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4_khoản 2_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2bc'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2ba'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Văn bản cam kết phát hành bảo lãnh quy định tại khoản 2 Điều 26 '
#             'Luật Kinh doanh bất động sản của ngân hàng thương mại trong nước, '
#             'chi nhánh ngân hàng nước ngoài đang hoạt động hợp pháp tại Việt '
#             'Nam.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4_khoản 2_điểm c',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2bd'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2ba'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm c',
#  'type': 'điểm'}
# {'content': 'Phương thức, hình thức công khai thông tin: Doanh nghiệp kinh '
#             'doanh bất động sản phải công khai đầy đủ, trung thực và chính xác '
#             'thông tin trên hệ thống thông tin về nhà ở và thị trường bất động '
#             'sản theo quy định của pháp luật về kinh doanh bất động sản và '
#             'trên trang thông tin điện tử của doanh nghiệp.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4_khoản 3',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2be'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b8'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 3',
#  'type': 'khoản'}
# {'content': 'Việc công khai thông tin trên hệ thống thông tin về nhà ở và thị '
#             'trường bất động sản thực hiện theo quy định của Nghị định quy '
#             'định chi tiết một số điều của Luật Kinh doanh bất động sản về xây '
#             'dựng và quản lý hệ thống thông tin, cơ sở dữ liệu về nhà ở và thị '
#             'trường bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4_khoản 4',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2bf'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b8'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 4',
#  'type': 'khoản'}
# {'content': 'Doanh nghiệp kinh doanh bất động sản có trách nhiệm cập nhật '
#             'thông tin đã công khai trong thời hạn 05 ngày làm việc kể từ ngày '
#             'thông tin có sự thay đổi.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 4_khoản 5',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c0'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b8'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 5',
#  'type': 'khoản'}
# {'content': 'tỷ lệ dư nợ tín dụng, dư nợ trái phiếu doanh nghiệp trên số vốn '
#             'chủ sở hữu của doanh nghiệp kinh doanh bất động sản',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 5',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c1'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 5',
#  'type': 'điều'}
# {'content': 'Doanh nghiệp kinh doanh bất động sản căn cứ vốn chủ sở hữu, '
#             'phương án đầu tư, kinh doanh quyết định việc vay tại tổ chức tín '
#             'dụng, phát hành trái phiếu doanh nghiệp cũng như tỷ lệ dư nợ tín '
#             'dụng, dư nợ trái phiếu doanh nghiệp trên số vốn chủ sở hữu của '
#             'doanh nghiệp bảo đảm:',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 5_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c2'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c1'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Đáp ứng các tỷ lệ an toàn tài chính của doanh nghiệp; tuân thủ '
#             'các quy định của pháp luật về tín dụng và pháp luật về trái phiếu '
#             'doanh nghiệp;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 5_khoản 1_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c3'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c2'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Trường hợp doanh nghiệp kinh doanh bất động sản vay tại tổ chức '
#             'tín dụng, phát hành trái phiếu doanh nghiệp để thực hiện dự án '
#             'bất động sản đã được cơ quan nhà nước có thẩm quyền chấp thuận '
#             'làm chủ đầu tư thì phải đảm bảo tổng dư 6 CÔNG BÁO/Số 937 + '
#             '938/Ngày 16-8-2024 nợ vay tại tổ chức tín dụng, dư nợ trái phiếu '
#             'doanh nghiệp và vốn chủ sở hữu phải có theo quy định đối với mỗi '
#             'dự án không vượt quá 100% tổng vốn đầu tư của dự án đó;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 5_khoản 1_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c4'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c2'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Tổng tỷ lệ dư nợ vay tại tổ chức tín dụng, dư nợ trái phiếu doanh '
#             'nghiệp để thực hiện dự án không quá 04 lần vốn chủ sở hữu của '
#             'doanh nghiệp đối với mỗi dự án bất động sản có quy mô sử dụng đất '
#             'dưới 20ha và không quá 5,67 lần vốn chủ sở hữu của doanh nghiệp '
#             'đối với mỗi dự án bất động sản có quy mô sử dụng đất từ 20ha trở '
#             'lên.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 5_khoản 1_điểm c',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c5'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c2'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm c',
#  'type': 'điểm'}
# {'content': 'Vốn chủ sở hữu của doanh nghiệp kinh doanh bất động sản được xác '
#             'định theo quy định tại khoản 1 Điều 6 Nghị định này.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 5_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c6'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c1'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'vốn chủ sở hữu của doanh nghiệp kinh doanh bất động sản và tổng '
#             'vốn đầu tư dự án bất động sản',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 6',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c7'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 6',
#  'type': 'điều'}
# {'content': 'Vốn chủ sở hữu của doanh nghiệp kinh doanh bất động sản trong '
#             'trường hợp doanh nghiệp kinh doanh bất động sản được cơ quan nhà '
#             'nước có thẩm quyền lựa chọn làm nhà đầu tư, lựa chọn làm chủ đầu '
#             'tư thực hiện dự án bất động sản theo quy định của pháp luật về '
#             'đầu tư, pháp luật về đấu giá; pháp luật về đấu thầu, pháp luật về '
#             'nhà ở, pháp luật về phát triển đô thị; được công nhận là chủ đầu '
#             'tư dự án nhà ở theo quy định của pháp luật về nhà ở, được xác '
#             'định căn cứ vào:',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 6_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c8'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c7'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Kết quả báo cáo tài chính hoặc kết quả báo cáo đối với khoản mục '
#             'vốn chủ sở hữu đã được kiểm toán thực hiện trong năm; trường hợp '
#             'không có kết quả báo cáo tài chính hoặc kết quả báo cáo đối với '
#             'khoản mục vốn chủ sở hữu đã được kiểm toán thực hiện trong năm '
#             'thì dùng kết quả báo cáo tài chính hoặc kết quả báo cáo đối với '
#             'khoản mục vốn chủ sở hữu đã được kiểm toán của năm liền trước '
#             'theo quy định của pháp luật về doanh nghiệp, pháp luật về kiểm '
#             'toán, pháp luật về kế toán;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 6_khoản 1_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2c9'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c8'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Đối với doanh nghiệp thành lập và hoạt động chưa đủ 12 tháng thì '
#             'vốn chủ sở hữu được xác định theo vốn điều lệ đã góp theo quy '
#             'định của pháp luật về doanh nghiệp.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 6_khoản 1_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ca'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c8'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Tổng vốn đầu tư đối với dự án bất động sản được xác định theo quy '
#             'định của pháp luật về đầu tư.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 6_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2cb'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2c7'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'kinh doanh bất động sản quy mô nhỏ; không nhằm mục đích kinh '
#             'doanh và dưới mức quy mô nhỏ',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 7',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2cc'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 7',
#  'type': 'điều'}
# {'content': 'Cá nhân kinh doanh bất động sản quy mô nhỏ phải đáp ứng các yêu '
#             'cầu sau:',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 7_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2cd'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2cc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Không thuộc trường hợp phải lập dự án đầu tư theo quy định của '
#             'pháp luật về xây dựng, nhà ở; CÔNG BÁO/Số 937 + 938/Ngày '
#             '16-8-2024 7',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 7_khoản 1_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ce'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2cd'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Không thuộc trường hợp có giá trị quá 300 tỷ đồng trên một hợp '
#             'đồng và có số lần giao dịch quá 10 lần trong một năm. Trường hợp '
#             'giao dịch 01 lần trong một năm thì không tính giá trị.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 7_khoản 1_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2cf'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2cd'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Tổ chức, cá nhân bán nhà ở, công trình xây dựng, phần diện tích '
#             'sàn xây dựng trong công trình xây dựng không nhằm mục đích kinh '
#             'doanh hoặc bán, cho thuê, cho thuê mua nhà ở, công trình xây '
#             'dựng, phần diện tích sàn xây dựng trong công trình xây dựng dưới '
#             'mức quy mô nhỏ, bao gồm:',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 7_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d0'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2cc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'Cá nhân không thuộc trường hợp phải lập dự án đầu tư theo quy '
#             'định của pháp luật về xây dựng, pháp luật về nhà ở;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 7_khoản 2_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d1'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2d0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Tổ chức không thuộc trường hợp có giá trị quá 300 tỷ đồng trên '
#             'một hợp đồng và có số lần giao dịch quá 10 lần trong một năm. '
#             'Trường hợp giao dịch 01 lần trong một năm thì không tính giá trị.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 7_khoản 2_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d2'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2d0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'thủ tục thông báo nhà ở hình thành trong tương lai đủ điều kiện '
#             'được bán, cho thuê mua',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 8',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d3'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 8',
#  'type': 'điều'}
# {'content': 'Trước khi thực hiện ký hợp đồng bán, cho thuê mua nhà ở hình '
#             'thành trong tương lai, chủ đầu tư dự án phải có văn bản thông báo '
#             'gửi cơ quan quản lý nhà nước về kinh doanh bất động sản cấp tỉnh '
#             'nơi có dự án về việc nhà ở hình thành trong tương lai đủ điều '
#             'kiện được bán, cho thuê mua kèm theo 01 bộ hồ sơ quy định tại '
#             'khoản 2 Điều này. Văn bản thông báo của chủ đầu tư dự án gửi cơ '
#             'quan quản lý nhà nước về kinh doanh bất động sản cấp tỉnh về nhà '
#             'ở đủ điều kiện được bán, cho thuê mua phải có các nội dung quy '
#             'định tại Phụ lục XV ban hành kèm theo Nghị định này.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 8_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d4'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2d3'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Hồ sơ gồm bản sao và xuất trình bản chính để đối chiếu hoặc bản '
#             'sao điện tử có giá trị pháp lý hoặc bản sao được chứng thực của '
#             'các giấy tờ sau:',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 8_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d5'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2d3'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'Các giấy tờ theo quy định tại khoản 2 và điểm a, điểm b khoản 3 '
#             'Điều 24 Luật Kinh doanh bất động sản;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 8_khoản 2_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d6'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2d5'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Biên bản nghiệm thu việc đã hoàn thành xây dựng cơ sở hạ tầng kỹ '
#             'thuật của dự án tương ứng theo tiến độ của dự án được chấp thuận, '
#             'phê duyệt theo quy định của pháp luật về xây dựng. Trường hợp là '
#             'nhà chung cư, tòa nhà hỗn hợp có nhà ở phải có biên bản nghiệm '
#             'thu việc đã hoàn thành thi công xây dựng phần móng theo quy định '
#             'của pháp luật về xây dựng. 8 CÔNG BÁO/Số 937 + 938/Ngày 16-8-2024',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 8_khoản 2_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d7'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2d5'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Trường hợp chủ đầu tư dự án đầu tư xây dựng nhà ở đã thế chấp nhà '
#             'ở hình thành trong tương lai hoặc một phần dự án hoặc toàn bộ dự '
#             'án thì việc xác định nhà ở đã được giải chấp thực hiện theo quy '
#             'định tại khoản 2 Điều 183 Luật Nhà ở số 27/2023/QH15.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 8_khoản 3',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d8'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2d3'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 3',
#  'type': 'khoản'}
# {'content': 'Trong thời hạn 15 ngày kể từ ngày nhận được văn bản thông báo kèm '
#             'theo hồ sơ quy định tại khoản 1 và khoản 2 Điều này, cơ quan quản '
#             'lý nhà nước về kinh doanh bất động sản cấp tỉnh có trách nhiệm '
#             'kiểm tra về điều kiện của nhà ở hình thành trong tương lai của dự '
#             'án bất động sản đưa vào kinh doanh theo quy định của Luật Kinh '
#             'doanh bất động sản và trả lời bằng văn bản cho chủ đầu tư về nhà '
#             'ở đủ điều kiện được bán, cho thuê mua, trường hợp không đủ điều '
#             'kiện bán, cho thuê mua phải nêu rõ lý do; đồng thời đăng tải văn '
#             'bản trả lời trên cổng thông tin về nhà ở và trị trường bất động '
#             'sản. Văn bản trả lời của cơ quan quản lý nhà nước về kinh doanh '
#             'bất động sản cấp tỉnh gửi cho chủ đầu tư về nhà ở đủ điều kiện '
#             'được bán, cho thuê mua phải có các nội dung quy định tại Phụ lục '
#             'XVI ban hành kèm theo Nghị định này. Trường hợp cơ quan quản lý '
#             'nhà nước về kinh doanh bất động sản cấp tỉnh không trả lời theo '
#             'thời hạn quy định thì doanh nghiệp có quyền khởi kiện, khiếu nại '
#             'theo quy định pháp luật.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 8_khoản 4',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2d9'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2d3'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 4',
#  'type': 'khoản'}
# {'content': 'thủ tục thông báo đất đã có hạ tầng kỹ thuật trong dự án bất động '
#             'sản được chuyển nhượng cho cá nhân tự xây dựng nhà ở',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2da'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2b0'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 9',
#  'type': 'điều'}
# {'content': 'Trước khi thực hiện ký kết hợp đồng chuyển nhượng quyền sử dụng '
#             'đất đã có hạ tầng kỹ thuật trong dự án bất động sản cho cá nhân '
#             'tự xây dựng nhà ở, chủ đầu tư dự án phải có văn bản thông báo gửi '
#             'cơ quan quản lý nhà nước về kinh doanh bất động sản cấp tỉnh nơi '
#             'có dự án về việc đất đã có hạ tầng kỹ thuật trong dự án bất động '
#             'sản đủ điều kiện được chuyển nhượng quyền sử dụng đất cho cá nhân '
#             'tự xây dựng nhà ở kèm theo hồ sơ quy định tại khoản 2 Điều này.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2db'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2da'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Hồ sơ gồm bản sao và xuất trình bản chính để đối chiếu hoặc bản '
#             'sao được chứng thực hoặc bản sao điện tử có giá trị pháp lý của '
#             'các giấy tờ sau:',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2dc'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2da'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'Quyết định chủ trương đầu tư hoặc chấp thuận chủ trương đầu tư '
#             'hoặc chấp thuận đầu tư của dự án bất động sản của cơ quan nhà '
#             'nước có thẩm quyền theo quy định của pháp luật về đầu tư, về xây '
#             'dựng, về nhà ở;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 2_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2dd'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2dc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Quyết định phê duyệt quy hoạch chi tiết hoặc quy hoạch tổng mặt '
#             'bằng của dự án bất động sản của cơ quan nhà nước có thẩm quyền '
#             'theo quy định của pháp luật về xây dựng, về quy hoạch đô thị; '
#             'CÔNG BÁO/Số 937 + 938/Ngày 16-8-2024 9',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 2_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2de'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2dc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Giấy phép xây dựng đối với trường hợp phải cấp giấy phép xây dựng '
#             'của cơ quan nhà nước có thẩm quyền theo quy định của pháp luật về '
#             'xây dựng;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 2_điểm c',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2df'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2dc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm c',
#  'type': 'điểm'}
# {'content': 'Thông báo kết quả thẩm định báo cáo nghiên cứu khả thi đầu tư xây '
#             'dựng hoặc Thông báo kết quả thẩm định thiết kế cơ sở của cơ quan '
#             'nhà nước có thẩm quyền theo quy định của pháp luật về xây dựng;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 2_điểm d',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e0'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2dc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm d',
#  'type': 'điểm'}
# {'content': 'Giấy tờ về nghiệm thu việc đã hoàn thành đầu tư xây dựng các công '
#             'trình hạ tầng kỹ thuật theo quy định của pháp luật về xây dựng;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 2_điểm đ',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e1'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2dc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm đ',
#  'type': 'điểm'}
# {'content': 'Hợp đồng cung cấp các dịch vụ cấp điện, cấp nước, thoát nước, thu '
#             'gom rác thải, xử lý nước thải;',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 2_điểm e',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e2'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2dc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm e',
#  'type': 'điểm'}
# {'content': 'Giấy chứng nhận quyền sử dụng đất có diện tích đất đã có hạ tầng '
#             'kỹ thuật trong dự án bất động sản chuyển nhượng quyền sử dụng đất '
#             'cho cá nhân tự xây dựng nhà ở theo quy định của pháp luật về đất '
#             'đai.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 2_điểm g',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e3'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2dc'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm g',
#  'type': 'điểm'}
# {'content': 'Trong thời hạn 15 ngày kể từ ngày nhận được văn bản thông báo kèm '
#             'theo hồ sơ quy định tại khoản 1 và khoản 2 Điều này, cơ quan quản '
#             'lý nhà nước về kinh doanh bất động sản cấp tỉnh có trách nhiệm '
#             'kiểm tra điều kiện về việc đất đã có hạ tầng kỹ thuật trong dự án '
#             'bất động sản đủ điều kiện được chuyển nhượng quyền sử dụng đất '
#             'cho cá nhân tự xây dựng nhà ở theo quy định của Luật Kinh doanh '
#             'bất động sản và trả lời bằng văn bản cho chủ đầu tư về đất đã có '
#             'hạ tầng kỹ thuật trong dự án bất động sản đủ điều kiện được '
#             'chuyển nhượng, trường hợp không đủ điều kiện chuyển nhượng phải '
#             'nêu rõ lý do; đồng thời đăng tải văn bản trả lời trên cổng thông '
#             'tin về nhà ở và thị trường bất động sản để công bố thông tin. '
#             'Trường hợp cơ quan quản lý nhà nước về kinh doanh bất động sản '
#             'cấp tỉnh không trả lời theo thời hạn quy định thì doanh nghiệp có '
#             'quyền khởi kiện, khiếu nại theo quy định pháp luật.',
#  'full_path': '96/2024/NĐ-CP_chương ii_điều 9_khoản 3',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e4'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2da'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 3',
#  'type': 'khoản'}
# {'content': 'THỦ TỤC CHUYỂN NHƯỢNG DỰ ÁN BẤT ĐỘNG SẢN',
#  'full_path': '96/2024/NĐ-CP_chương iii',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e5'),
#  'is_amendment': False,
#  'parent_id': None,
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'chương iii',
#  'type': 'chương'}
# {'content': 'thủ tục chuyển nhượng toàn bộ hoặc một phần dự án bất động sản '
#             'thuộc thẩm quyền quyết định cho phép chuyển nhượng của Thủ tướng '
#             'Chính phủ',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e6'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e5'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điều 10',
#  'type': 'điều'}
# {'content': 'Việc chuyển nhượng toàn bộ hoặc một phần dự án bất động sản thuộc '
#             'thẩm quyền quyết định cho phép chuyển nhượng của Thủ tướng Chính '
#             'phủ được thực hiện theo quy định tại khoản 1 Điều 42 của Luật '
#             'Kinh doanh bất động sản. 10 CÔNG BÁO/Số 937 + 938/Ngày 16-8-2024',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 1',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e7'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e6'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 1',
#  'type': 'khoản'}
# {'content': 'Chủ đầu tư dự án bất động sản gửi 01 bộ hồ sơ gồm các giấy tờ '
#             '(bản sao và xuất trình bản chính để đối chiếu hoặc bản sao được '
#             'chứng thực hoặc bản sao điện tử có giá trị pháp lý) quy định tại '
#             'khoản 3, khoản 4 Điều này đến Ủy ban nhân dân cấp tỉnh hoặc cơ '
#             'quan quản lý nhà nước về kinh doanh bất động sản cấp tỉnh nơi có '
#             'dự án được Ủy ban nhân dân cấp tỉnh ủy quyền.',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 2',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e8'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e6'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 2',
#  'type': 'khoản'}
# {'content': 'Các giấy tờ của chủ đầu tư chuyển nhượng dự án gồm:',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e6'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 3',
#  'type': 'khoản'}
# {'content': 'Văn bản của chủ đầu tư dự án đề nghị cho phép chuyển nhượng toàn '
#             'bộ hoặc một phần dự án bất động sản theo mẫu tại Phụ lục XII ban '
#             'hành kèm theo Nghị định này;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ea'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Quyết định chủ trương đầu tư hoặc chấp thuận chủ trương đầu tư '
#             'hoặc chấp thuận đầu tư của dự án bất động sản của cơ quan nhà '
#             'nước có thẩm quyền theo quy định của pháp luật về đầu tư, về xây '
#             'dựng, về nhà ở;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2eb'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Văn bản của cơ quan nhà nước có thẩm quyền về việc lựa chọn nhà '
#             'đầu tư, lựa chọn chủ đầu tư theo quy định của pháp luật về đầu '
#             'tư, pháp luật về đấu giá, pháp luật về đấu thầu, pháp luật về nhà '
#             'ở, pháp luật về phát triển đô thị; quyết định hoặc văn bản công '
#             'nhận chủ đầu tư đối với trường hợp dự án phải thực hiện thủ tục '
#             'công nhận chủ đầu tư theo quy định của pháp luật về xây dựng, '
#             'pháp luật về nhà ở;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm c',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ec'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm c',
#  'type': 'điểm'}
# {'content': 'Quyết định phê duyệt quy hoạch chi tiết hoặc quy hoạch tổng mặt '
#             'bằng của dự án bất động sản của cơ quan nhà nước có thẩm quyền '
#             'theo quy định của pháp luật về xây dựng, về quy hoạch đô thị;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm d',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ed'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm d',
#  'type': 'điểm'}
# {'content': 'Các giấy tờ về đất gồm: Quyết định giao đất, cho thuê đất, cho '
#             'phép chuyển mục đích sử dụng đất thực hiện dự án của cơ quan nhà '
#             'nước có thẩm quyền theo quy định của pháp luật về đất đai. Biên '
#             'bản bàn giao đất thực hiện dự án trên thực địa của cơ quan nhà '
#             'nước có thẩm quyền cho chủ đầu tư dự án theo quy định của pháp '
#             'luật về đất đai;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm đ',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ee'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm đ',
#  'type': 'điểm'}
# {'content': 'Trường hợp dự án, phần dự án bất động sản thế chấp thì phải có '
#             'giấy tờ thể hiện đã giải chấp theo quy định của pháp luật;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm e',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2ef'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm e',
#  'type': 'điểm'}
# {'content': 'Giấy tờ nghiệm thu theo quy định của pháp luật xây dựng về việc '
#             'đã hoàn thành đầu tư xây dựng các công trình hạ tầng kỹ thuật '
#             'tương ứng theo tiến độ, thiết kế, quy hoạch chi tiết và nội dung '
#             'dự án được phê duyệt đối với trường hợp chuyển nhượng toàn bộ dự '
#             'án đầu tư xây dựng kết cấu hạ tầng;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm g',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f0'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm g',
#  'type': 'điểm'}
# {'content': 'Xác nhận của cơ quan thuế về việc chủ đầu tư dự án đã hoàn thành '
#             'nghĩa vụ tài chính về đất đai của dự án đối với Nhà nước và các '
#             'chứng từ thể hiện chủ đầu tư đã nộp phí, lệ phí liên quan đến đất '
#             'đai (nếu có) quy định tại khoản 3 Điều 40 Luật Kinh doanh bất '
#             'động sản; CÔNG BÁO/Số 937 + 938/Ngày 16-8-2024 11',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm h',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f1'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm h',
#  'type': 'điểm'}
# {'content': 'Đối với doanh nghiệp nhà nước chuyển nhượng toàn bộ hoặc một phần '
#             'dự án bất động sản thì phải có giấy tờ chứng minh việc tuân thủ '
#             'quy định của pháp luật về quản lý, sử dụng vốn nhà nước đầu tư '
#             'vào sản xuất, kinh doanh tại doanh nghiệp;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm i',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f2'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm i',
#  'type': 'điểm'}
# {'content': 'Báo cáo quá trình thực hiện dự án bất động sản tính đến thời điểm '
#             'chuyển nhượng theo mẫu tại Phụ lục XIII ban hành kèm theo Nghị '
#             'định này;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm k',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f3'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm k',
#  'type': 'điểm'}
# {'content': 'Thỏa thuận về việc chuyển nhượng toàn bộ hoặc một phần dự án bất '
#             'động sản giữa bên chuyển nhượng và bên nhận chuyển nhượng (nếu '
#             'có).',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 3_điểm l',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f4'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e9'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm l',
#  'type': 'điểm'}
# {'content': 'Các giấy tờ của bên nhận chuyển nhượng dự án gồm:',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 4',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f5'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e6'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 4',
#  'type': 'khoản'}
# {'content': 'Giấy chứng nhận đăng ký doanh nghiệp hoặc Giấy chứng nhận đăng ký '
#             'đầu tư hoặc giấy tờ chứng minh việc thành lập tổ chức theo quy '
#             'định của pháp luật về doanh nghiệp, pháp luật về đầu tư;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 4_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f6'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2f5'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Báo cáo tài chính theo quy định tại điểm a khoản 1 Điều 6 của '
#             'Nghị định này;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 4_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f7'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2f5'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Văn bản cam kết về việc tiếp tục triển khai đầu tư xây dựng, kinh '
#             'doanh theo đúng nội dung dự án đã được chấp thuận;',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 4_điểm c',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f8'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2f5'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm c',
#  'type': 'điểm'}
# {'content': 'Giấy tờ chứng minh đáp ứng điều kiện theo quy định tại khoản 5 '
#             'Điều 40 Luật Kinh doanh bất động sản.',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 4_điểm d',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2f9'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2f5'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm d',
#  'type': 'điểm'}
# {'content': 'Trong thời hạn 45 ngày kể từ ngày nhận đủ hồ sơ hợp lệ, Ủy ban '
#             'nhân dân cấp tỉnh có trách nhiệm lấy ý kiến của Bộ Xây dựng và '
#             'các bộ, ngành, cơ quan có liên quan và tổ chức thẩm định hồ sơ '
#             'chuyển nhượng theo quy định tại khoản 9 Điều này, trình Thủ tướng '
#             'Chính phủ xem xét, quyết định. Mẫu quyết định cho phép chuyển '
#             'nhượng được thực hiện theo mẫu tại Phụ lục XIV ban hành kèm theo '
#             'Nghị định này. Trường hợp Thủ tướng Chính phủ ủy quyền cho Ủy ban '
#             'nhân dân cấp tỉnh thì Ủy ban nhân dân cấp tỉnh căn cứ ý kiến của '
#             'các bộ, ngành để xem xét, quyết định cho phép chuyển nhượng một '
#             'phần dự án.',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 5',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2fa'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e6'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 5',
#  'type': 'khoản'}
# {'content': 'Trong thời hạn tối đa 60 ngày kể từ ngày có quyết định cho phép '
#             'chuyển nhượng dự án, phần dự án bất động sản của cấp có thẩm '
#             'quyền, bên chuyển nhượng và bên nhận chuyển nhượng có trách nhiệm '
#             'phải hoàn thành:',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 6',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2fb'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e6'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 6',
#  'type': 'khoản'}
# {'content': 'Ký kết hợp đồng chuyển nhượng theo mẫu tại Phụ lục IX hoặc Phụ '
#             'lục X ban hành kèm theo Nghị định này. Hợp đồng chuyển nhượng dự '
#             'án, phần dự án đồng thời là hợp đồng chuyển quyền sử dụng đất của '
#             'dự án, phần dự án chuyển nhượng, trừ trường hợp thuê đất trả tiền '
#             'thuê đất hàng năm thì việc chuyển quyền sử dụng đất thực hiện '
#             'theo quy định của pháp luật về đất đai; 12 CÔNG BÁO/Số 937 + '
#             '938/Ngày 16-8-2024',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 6_điểm a',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2fc'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2fb'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm a',
#  'type': 'điểm'}
# {'content': 'Bàn giao dự án, phần dự án chuyển nhượng và toàn bộ hồ sơ dự án, '
#             'phần dự án chuyển nhượng từ bên chuyển nhượng sang cho bên nhận '
#             'chuyển nhượng; việc bàn giao giữa bên chuyển nhượng và bên nhận '
#             'chuyển nhượng phải được lập thành văn bản. Hết thời hạn nêu trên, '
#             'nếu các bên không hoàn thành quy định tại khoản này và không được '
#             'cấp có thẩm quyền ban hành quyết định cho phép chuyển nhượng dự '
#             'án, phần dự án bất động sản gia hạn thời gian thực hiện thì quyết '
#             'định này hết hiệu lực.',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 6_điểm b',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2fd'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2fb'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'điểm b',
#  'type': 'điểm'}
# {'content': 'Bên nhận chuyển nhượng dự án được tiếp tục triển khai dự án, phần '
#             'dự án sau khi nhận bàn giao dự án, phần dự án bất động sản và '
#             'hoàn thành nghĩa vụ nộp thuế, phí, lệ phí (nếu có).',
#  'full_path': '96/2024/NĐ-CP_chương iii_điều 10_khoản 7',
#  'id': ObjectId('694fb65cf9f7062ab1a6b2fe'),
#  'is_amendment': False,
#  'is_phu_luc': False,
#  'parent_id': ObjectId('694fb65cf9f7062ab1a6b2e6'),
#  'so_hieu': '96/2024/NĐ-CP',
#  'title': 'khoản 7',
#  'type': 'khoản'}
