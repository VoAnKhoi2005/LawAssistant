# %%
from triplet_extraction.src.doc_extraction.parse_text_to_section import parse_document
from pathlib import Path
import pandas as pd

data_folder = Path(r"E:\Github\LawAssistant\triplet_extraction\data\luat_dat_dai")
extracted_csv = data_folder / "extracted_texts_google.csv"

df = pd.read_csv(extracted_csv, encoding="utf-8-sig")
print(f"Loaded {len(df)} documents from CSV")

TARGET_SO_HIEU = "03/2025/NĐ-CP"

row = df.loc[df["so_hieu"] == TARGET_SO_HIEU]

if row.empty:
    raise ValueError(f"Không tìm thấy văn bản có số hiệu {TARGET_SO_HIEU}")

row = row.iloc[0]

result = parse_document(
    row["combined_text"],
    row["so_hieu"]
)

print("Parsed successfully")
# Out:
# Loaded 62 documents from CSV
# Parsed successfully

# %%
from pprint import pprint

pprint(result)
# Out:
# {ObjectId('69608ff1dd14db83b552d5ab'): {'content': 'QUY ĐỊNH CHUNG Điều 1. '
#                                                    'Phạm vi điều chỉnh Nghị '
#                                                    'định này quy định các nội '
#                                                    'dung sau:',
#                                         'full_path': '03/2025/NĐ-CP_chương i',
#                                         'id': ObjectId('69608ff1dd14db83b552d5ab'),
#                                         'is_amendment': False,
#                                         'parent_id': None,
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'chương i',
#                                         'type': 'chương'},
#  ObjectId('69608ff1dd14db83b552d5ac'): {'content': 'Sắp xếp lại, xử lý tài sản '
#                                                    'cộng là nhà, đất, công '
#                                                    'trình khác gắn liền với '
#                                                    'đất (sau đây gọi là nhà, '
#                                                    'đất) do đối tượng quy định '
#                                                    'tại khoản 1 Điều 2 Nghị '
#                                                    'định này quản lý, sử dụng, '
#                                                    'trừ nhà, đất không thực '
#                                                    'hiện sắp xếp lại, xử lý '
#                                                    'theo quy định tại Điều 3 '
#                                                    'Nghị định này.',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'i__khoản 1',
#                                         'id': ObjectId('69608ff1dd14db83b552d5ac'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5ab'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 1',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d5ad'): {'content': 'Xử lý chuyển tiếp việc sắp '
#                                                    'xếp lại, xử lý nhà, đất do '
#                                                    'đối tượng quy định tại '
#                                                    'khoản 2 Điều 2 Nghị định '
#                                                    'này quản lý, sử dụng.',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'i__khoản 2',
#                                         'id': ObjectId('69608ff1dd14db83b552d5ad'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5ab'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 2',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d5ae'): {'content': 'Đối tượng áp dụng quy định '
#                                                    'về sắp xếp lại, xử lý nhà, '
#                                                    'đất quy định tại Chương II '
#                                                    'Nghị định này bao gồm: Cơ '
#                                                    'quan nhà nước, đơn vị lực '
#                                                    'lượng vũ trang nhân dân, '
#                                                    'đơn vị sự nghiệp công lập, '
#                                                    'Mặt trận Tổ quốc Việt Nam, '
#                                                    'tổ chức chính trị - xã '
#                                                    'hội, tổ chức chính trị xã '
#                                                    'hội - nghề nghiệp, tổ chức '
#                                                    'xã hội, tổ chức xã hội - '
#                                                    'nghề nghiệp, tổ chức khác '
#                                                    'được thành lập theo quy '
#                                                    'định của pháp luật về hội '
#                                                    '(sau đây gọi là cơ quan, '
#                                                    'tổ chức, đơn vị). Quỹ tài '
#                                                    'chính nhà nước ngoài ngân '
#                                                    'sách áp dụng cơ chế tài '
#                                                    'chính hoặc chế độ quản lý, '
#                                                    'sử dụng tài sản như đơn vị '
#                                                    'sự nghiệp công lập thì '
#                                                    'thực hiện sắp xếp lại, xử '
#                                                    'lý nhà, đất như quy định '
#                                                    'áp dụng đối với đơn vị sự '
#                                                    'nghiệp công lập quy định '
#                                                    'tại Nghị định này. Việc '
#                                                    'quản lý, sử dụng số tiền '
#                                                    'thu được từ sắp xếp lại, '
#                                                    'xử lý nhà, đất hình thành '
#                                                    'từ quỹ tài chính nhà nước '
#                                                    'ngoài ngân sách thực hiện '
#                                                    'theo cơ chế tài chính của '
#                                                    'quỹ, không thực hiện theo '
#                                                    'quy định tại Nghị định '
#                                                    'này.',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'i__khoản 1',
#                                         'id': ObjectId('69608ff1dd14db83b552d5ae'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5ab'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 1',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d5af'): {'content': 'Đối tượng áp dụng quy định '
#                                                    'về xử lý chuyển tiếp việc '
#                                                    'sắp xếp lại, xử lý nhà, '
#                                                    'đất tại Chương III Nghị '
#                                                    'định này bao gồm:',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'i__khoản 2',
#                                         'id': ObjectId('69608ff1dd14db83b552d5af'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5ab'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 2',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d5b0'): {'content': 'Cơ quan, tổ chức, đơn vị '
#                                                    'quy định tại khoản 1 Điều '
#                                                    'này, cơ quan của Đảng, đơn '
#                                                    'vị sự nghiệp của Đảng;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'i__khoản 2_điểm a',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b0'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5af'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm a',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5b1'): {'content': 'Doanh nghiệp; ngân hàng '
#                                                    'thương mại, ngân hàng '
#                                                    'chính sách, ngân hàng hợp '
#                                                    'tác xã, Ngân hàng Phát '
#                                                    'triển Việt Nam; các quỹ '
#                                                    'tài chính nhà nước ngoài '
#                                                    'ngân sách áp dụng cơ chế '
#                                                    'tài chính hoặc chế độ quản '
#                                                    'lý, sử dụng tài sản như '
#                                                    'doanh nghiệp (sau đây gọi '
#                                                    'là doanh nghiệp) thuộc đối '
#                                                    'tượng sắp xếp lại, xử lý '
#                                                    'nhà, đất trước ngày Nghị '
#                                                    'định này có hiệu lực thi '
#                                                    'hành.',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'i__khoản 2_điểm b',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b1'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5af'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm b',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5b2'): {'content': 'SẮP XẾP LẠI, XỬ LÝ NHÀ, '
#                                                    'ĐẤT TẠI CƠ QUAN, TỔ CHỨC, '
#                                                    'ĐƠN VỊ Điều 3. Nhà, đất '
#                                                    'không thực hiện sắp xếp '
#                                                    'lại, xử lý 1. Nhà, đất do '
#                                                    'các đối tượng sau đây quản '
#                                                    'lý, sử dụng:',
#                                         'full_path': '03/2025/NĐ-CP_chương ii',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b2'),
#                                         'is_amendment': False,
#                                         'parent_id': None,
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'chương ii',
#                                         'type': 'chương'},
#  ObjectId('69608ff1dd14db83b552d5b3'): {'content': 'Đối tượng quy định tại '
#                                                    'điểm b khoản 2 Điều 2 Nghị '
#                                                    'định này;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii___điểm a',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b3'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': None,
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm a',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5b4'): {'content': 'Các đối tượng khác ngoài '
#                                                    'đối tượng quy định tại '
#                                                    'điểm a khoản này khoản 1 '
#                                                    'Điều 2 Nghị định này;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii___điểm b',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b4'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': None,
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm b',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5b5'): {'content': 'Việc quản lý, sử dụng, xử '
#                                                    'lý nhà, đất do các đối '
#                                                    'tượng quy định tại điểm a, '
#                                                    'điểm b khoản này thực hiện '
#                                                    'theo quy định tương ứng '
#                                                    'của pháp luật về đất đai '
#                                                    'và pháp luật khác có liên '
#                                                    'quan.',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii___điểm c',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b5'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': None,
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm c',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5b6'): {'content': 'Nhà, đất do các cơ quan, '
#                                                    'tổ chức, đơn vị quy định '
#                                                    'tại khoản 1 Điều 2 Nghị '
#                                                    'định này quản lý, sử dụng '
#                                                    'gồm:',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b2'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 2',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d5b7'): {'content': 'Nhà, đất mà nhà hoặc đất '
#                                                    'hoặc cả nhà và đất thuộc '
#                                                    'trường hợp thuê, thuê lại, '
#                                                    'nhận góp vốn, nhận giữ hộ, '
#                                                    'mượn của các đối tượng '
#                                                    'khác, trừ các trường hợp '
#                                                    'quy định tại khoản 1 Điều '
#                                                    '16 Nghị định này;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm a',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b7'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm a',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5b8'): {'content': 'Đất, tài sản gắn liền với '
#                                                    'đất thuộc: nhóm đất nông '
#                                                    'nghiệp; nhóm đất chưa sử '
#                                                    'dụng; đất khu công nghiệp, '
#                                                    'cụm công nghiệp, khu chế '
#                                                    'xuất, khu công nghệ cao, '
#                                                    'khu kinh tế; đất sử dụng '
#                                                    'cho hoạt động khoáng sản '
#                                                    '(bao gồm cả hạng mục công '
#                                                    'trình phục vụ cho việc '
#                                                    'khai thác, chế biến khoáng '
#                                                    'sản gắn với khu vực khai '
#                                                    'thác và hành lang bảo vệ '
#                                                    'an toàn cho việc khai thác '
#                                                    'khoáng sản); đất sử dụng '
#                                                    'cho hoạt động tôn giáo, '
#                                                    'hoạt động tín ngưỡng; đất '
#                                                    'nghĩa trang, nhà tang lễ, '
#                                                    'cơ sở hỏa táng, đất cơ sở '
#                                                    'lưu giữ tro cốt; đất có '
#                                                    'mặt nước chuyên dùng, đất '
#                                                    'sông, ngòi, kênh, rạch, '
#                                                    'suối theo quy định của '
#                                                    'pháp luật về đất đai;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm b',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b8'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm b',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5b9'): {'content': 'Đất, tài sản gắn liền với '
#                                                    'đất (bao gồm cả trụ sở, '
#                                                    'văn phòng làm việc và các '
#                                                    'công trình khác xây dựng '
#                                                    'trên đất) sử dụng vào mục '
#                                                    'đích công cộng thuộc: đất '
#                                                    'công trình giao thông '
#                                                    '(đường bộ, đường sắt, '
#                                                    'đường thủy nội địa, hàng '
#                                                    'hải, hàng không); đất công '
#                                                    'trình thủy lợi; đất công '
#                                                    'trình cấp nước, thoát '
#                                                    'nước; đất công trình '
#                                                    'phòng, chống thiên tai; '
#                                                    'đất có di tích lịch sử - '
#                                                    'văn hóa, danh lam thắng '
#                                                    'cảnh, di sản thiên nhiên; '
#                                                    'đất công trình xử lý chất '
#                                                    'thải; đất công trình năng '
#                                                    'lượng, chiếu sáng công '
#                                                    'cộng; đất công trình hạ '
#                                                    'tầng bưu chính, viễn '
#                                                    'thông, công nghệ thông '
#                                                    'tin; đất chợ; đất cảng cá, '
#                                                    'bến cá, cảng cạn; đất khu '
#                                                    'vui chơi, giải trí công '
#                                                    'cộng, sinh hoạt cộng đồng '
#                                                    '(bao gồm nhà văn hóa, câu '
#                                                    'lạc bộ, nhà sinh hoạt cộng '
#                                                    'đồng, sân vận động, sân '
#                                                    'thể thao xã, thôn, tổ dân '
#                                                    'phố, khu dân cư và tương '
#                                                    'đương); đất công trình '
#                                                    'công cộng khác theo quy '
#                                                    'định của pháp luật về đất '
#                                                    'đai và pháp luật khác có '
#                                                    'liên quan;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm c',
#                                         'id': ObjectId('69608ff1dd14db83b552d5b9'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm c',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5ba'): {'content': 'Đất, tài sản gắn liền với '
#                                                    'đất thuộc trường hợp thu '
#                                                    'hồi đất theo quy định của '
#                                                    'pháp luật về đất đai; '
#                                                    'trường hợp nhà, đất vừa '
#                                                    'thuộc trường hợp thu hồi '
#                                                    'đất theo quy định của pháp '
#                                                    'luật về đất đai, vừa thuộc '
#                                                    'trường hợp thu hồi nhà, '
#                                                    'đất theo quy định tại Điều '
#                                                    '11 Nghị định này thì thực '
#                                                    'hiện thu hồi đất và xử lý '
#                                                    'nhà, đất sau thu hồi theo '
#                                                    'quy định của pháp luật về '
#                                                    'đất đai;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm d',
#                                         'id': ObjectId('69608ff1dd14db83b552d5ba'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm d',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5bb'): {'content': 'Đất (bao gồm tài sản gắn '
#                                                    'liền với đất) thuộc trách '
#                                                    'nhiệm quản lý của Ủy ban '
#                                                    'nhân dân cấp xã, Chủ tịch '
#                                                    'Ủy ban nhân dân cấp xã '
#                                                    'theo quy định của pháp '
#                                                    'luật về đất đai; đất (bao '
#                                                    'gồm tài sản gắn liền với '
#                                                    'đất) giao cho tổ chức phát '
#                                                    'triển quỹ đất theo quy '
#                                                    'định của pháp luật về đất '
#                                                    'đai;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm đ',
#                                         'id': ObjectId('69608ff1dd14db83b552d5bb'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm đ',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5bc'): {'content': 'Nhà, đất giao cho tổ chức '
#                                                    'có chức năng quản lý, kinh '
#                                                    'doanh nhà địa phương quản '
#                                                    'lý, khai thác, trừ nhà, '
#                                                    'đất quy định tại khoản 1 '
#                                                    'Điều 16 Nghị định này;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm e',
#                                         'id': ObjectId('69608ff1dd14db83b552d5bc'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm e',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5bd'): {'content': 'Đất, nhà, tài sản gắn liền '
#                                                    'với đất thuộc: nhà chung '
#                                                    'cư, nhà ở thương mại, nhà '
#                                                    'ở công vụ, nhà ở phục vụ '
#                                                    'tái định cư, nhà ở xã hội, '
#                                                    'nhà ở cho lực lượng vũ '
#                                                    'trang nhân dân, nhà ở khác '
#                                                    'thuộc tài sản công, nhà '
#                                                    'lưu trú công nhân, nhà ở '
#                                                    'sinh viên tập trung theo '
#                                                    'quy định của pháp luật về '
#                                                    'nhà ở; quỹ nhà, đất tiếp '
#                                                    'nhận từ dự án phát triển '
#                                                    'nhà ở thương mại, dự án '
#                                                    'phát triển đô thị bàn giao '
#                                                    'lại cho Nhà nước theo quy '
#                                                    'định của pháp luật;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm g',
#                                         'id': ObjectId('69608ff1dd14db83b552d5bd'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm g',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5be'): {'content': 'Nhà, đất mà nhà hoặc đất '
#                                                    'hoặc cả nhà và đất được '
#                                                    'hình thành từ nguồn quỹ '
#                                                    'phúc lợi được cơ quan, '
#                                                    'người có thẩm quyền quy '
#                                                    'định, quyết định hoặc phê '
#                                                    'duyệt đề án áp dụng hoặc '
#                                                    'vận dụng cơ chế tài chính '
#                                                    'như doanh nghiệp; quỹ công '
#                                                    'đoàn của cơ quan, tổ chức, '
#                                                    'đơn vị;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm h',
#                                         'id': ObjectId('69608ff1dd14db83b552d5be'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm h',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5bf'): {'content': 'Nhà, đất không phải thực '
#                                                    'hiện sắp xếp lại, xử lý '
#                                                    'theo quy định hoặc quyết '
#                                                    'định của Quốc hội, Ủy ban '
#                                                    'thường vụ Quốc hội, Chính '
#                                                    'phủ;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm i',
#                                         'id': ObjectId('69608ff1dd14db83b552d5bf'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm i',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5c0'): {'content': 'Bộ, cơ quan trung ương, Ủy '
#                                                    'ban nhân dân cấp tỉnh, cơ '
#                                                    'quan, tổ chức, đơn vị quản '
#                                                    'lý, sử dụng nhà, đất căn '
#                                                    'cứ hồ sơ, tài liệu liên '
#                                                    'quan (thông tin quy hoạch, '
#                                                    'kế hoạch sử dụng đất; '
#                                                    'quyết định thu hồi đất, '
#                                                    'giao đất, cho thuê đất; '
#                                                    'giấy tờ chứng minh nguồn '
#                                                    'gốc hình thành tài sản, '
#                                                    'tải liệu liên quan khác) '
#                                                    'để xác định và chịu trách '
#                                                    'nhiệm về việc xác định '
#                                                    'nhà, đất không thực hiện '
#                                                    'sắp xếp lại, xử lý quy '
#                                                    'định khoản này. Việc quản '
#                                                    'lý, sử dụng, xử lý đối với '
#                                                    'nhà, đất quy định tại các '
#                                                    'điểm a, b, c, d, đ, e, g, '
#                                                    'h và i khoản này thực hiện '
#                                                    'theo quy định tương ứng '
#                                                    'của pháp luật về đất đai '
#                                                    'và pháp luật khác có liên '
#                                                    'quan.',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 2_điểm k',
#                                         'id': ObjectId('69608ff1dd14db83b552d5c0'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b6'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm k',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5c1'): {'content': 'Nhà, đất do cơ quan, tổ '
#                                                    'chức, đơn vị quy định tại '
#                                                    'khoản 1 Điều 2 Nghị định '
#                                                    'này quản lý, sử dụng trong '
#                                                    'một số trường hợp cụ thể '
#                                                    'như sau:',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 3',
#                                         'id': ObjectId('69608ff1dd14db83b552d5c1'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5b2'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 3',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d5c2'): {'content': 'Nhà, đất thuộc tài sản đặc '
#                                                    'biệt tại đơn vị lực lượng '
#                                                    'vũ trang nhân dân không '
#                                                    'thực hiện sắp xếp lại, xử '
#                                                    'lý theo quy định tại Nghị '
#                                                    'định này. Việc quản lý, sử '
#                                                    'dụng, xử lý đối với nhà, '
#                                                    'đất thuộc tài sản đặc biệt '
#                                                    'tại đơn vị lực lượng vũ '
#                                                    'trang nhân dân thực hiện '
#                                                    'theo quy định của Luật '
#                                                    'Quản lý, sử dụng tài sản '
#                                                    'công, Nghị định số '
#                                                    '151/2017/NĐ-CP ngày 26 '
#                                                    'tháng 12 năm 2017 của '
#                                                    'Chính phủ quy định chi '
#                                                    'tiết một số điều của Luật '
#                                                    'Quản lý, sử dụng tài sản '
#                                                    'công (sau đây gọi là Nghị '
#                                                    'định số 151/2017/NĐ-CP) và '
#                                                    'pháp luật khác có liên '
#                                                    'quan;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 3_điểm a',
#                                         'id': ObjectId('69608ff1dd14db83b552d5c2'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5c1'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm a',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5c3'): {'content': 'Đất quốc phòng, đất an '
#                                                    'ninh đã được cơ quan, '
#                                                    'người có thẩm quyền phê '
#                                                    'duyệt điều chỉnh quy hoạch '
#                                                    'đất giao cho địa phương để '
#                                                    'làm nhà ở hoặc đã bố trí '
#                                                    'làm nhà ở, có khuôn viên '
#                                                    'độc lập hoặc có thể tách '
#                                                    'biệt khỏi khuôn viên cơ sở '
#                                                    'nhà, đất, có lối đi riêng '
#                                                    'mà nhà và tài sản gắn liền '
#                                                    'với đất đó không phải là '
#                                                    'tài sản công hoặc đã được '
#                                                    'thanh lý, hóa giá thì '
#                                                    'không thực hiện sắp xếp '
#                                                    'lại, xử lý nhà, đất theo '
#                                                    'quy định tại Nghị định '
#                                                    'này. Uỷ ban nhân dân cấp '
#                                                    'tỉnh chỉ đạo việc tiếp '
#                                                    'nhận, quản lý, xử lý đối '
#                                                    'với nhà, đất này theo quy '
#                                                    'định của pháp luật về đất '
#                                                    'đai và pháp luật khác có '
#                                                    'liên quan;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 3_điểm b',
#                                         'id': ObjectId('69608ff1dd14db83b552d5c3'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5c1'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm b',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5c4'): {'content': 'Nhà, đất đang sử dụng để '
#                                                    'liên doanh, liên kết mà '
#                                                    'Hợp đồng đã ký phù hợp với '
#                                                    'quy định của pháp luật tại '
#                                                    'thời điểm ký kết thì thực '
#                                                    'hiện theo Hợp đồng đã ký; '
#                                                    'trong thời gian liên '
#                                                    'doanh, liên kết (bao gồm '
#                                                    'cả thời gian gia hạn Hợp '
#                                                    'đồng) thì không thực hiện '
#                                                    'sắp xếp lại, xử lý theo '
#                                                    'quy định tại Nghị định '
#                                                    'này; sau khi kết thúc hoặc '
#                                                    'chấm dứt việc liên doanh, '
#                                                    'liên kết mà nhà, đất và '
#                                                    'đối tượng được giao quản '
#                                                    'lý, sử dụng thuộc phạm vi, '
#                                                    'đối tượng quy định tại '
#                                                    'khoản 1 Điều 1, khoản 1 '
#                                                    'Điều 2 Nghị định này thì '
#                                                    'thực hiện sắp xếp lại, xử '
#                                                    'lý theo quy định tại Nghị '
#                                                    'định này;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 3_điểm c',
#                                         'id': ObjectId('69608ff1dd14db83b552d5c4'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5c1'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm c',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5c5'): {'content': 'Đất, nhà gắn liền với đất '
#                                                    'mà đất đó đã hết thời hạn '
#                                                    'giao đất, cho thuê đất thì '
#                                                    'xử lý theo quy định của '
#                                                    'pháp luật về đất đai; '
#                                                    'trường hợp đất gắn liền '
#                                                    'với nhà được cơ quan nhà '
#                                                    'nước có thẩm quyền gia hạn '
#                                                    'sử dụng đất theo quy định '
#                                                    'của pháp luật về đất đai '
#                                                    'mà sau khi gia hạn nhà, '
#                                                    'đất đó và đối tượng được '
#                                                    'gia hạn sử dụng đất thuộc '
#                                                    'phạm vi, đối tượng quy '
#                                                    'định tại khoản 1 Điều 1, '
#                                                    'khoản 1 Điều 2 Nghị định '
#                                                    'này thì thực hiện sắp xếp '
#                                                    'lại, xử lý theo quy định '
#                                                    'tại Nghị định này;',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 3_điểm d',
#                                         'id': ObjectId('69608ff1dd14db83b552d5c5'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d5c1'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'điểm d',
#                                         'type': 'điểm'},
#  ObjectId('69608ff1dd14db83b552d5c6'): {'content': 'Nhà, đất đang trong quá '
#                                                    'trình tố tụng, thi hành '
#                                                    'án, giải quyết tranh chấp, '
#                                                    'giải quyết khiếu nại, giải '
#                                                    'quyết tố cáo về đất đai, '
#                                                    'thực hiện kết luận, kiến '
#                                                    'nghị của cơ quan thanh '
#                                                    'tra, kiểm tra, kiểm toán '
#                                                    'hoặc bản án về việc thu '
#                                                    'hồi thì không thực hiện '
#                                                    'sắp xếp lại, xử lý theo '
#                                                    'quy định tại Nghị định '
#                                                    'này; trường hợp sau khi có '
#                                                    'hiệu lực của bản án, quyết '
#                                                    'định của Tòa án, quyết '
#                                                    'định hoặc phán quyết của '
#                                                    'Trọng tài thương mại Việt '
#                                                    'Nam, quyết định thi hành '
#                                                    'án, quyết định giải quyết '
#                                                    'tranh chấp, giải quyết '
#                                                    'khiếu nại, giải quyết tố '
#                                                    'cáo về đất đai, giải quyết '
#                                                    'các kiến nghị của cơ quan '
#                                                    'thanh tra, kiểm tra, kiểm '
#                                                    'toán hoặc bản án của cơ '
#                                                    'quan, người có thẩm quyền '
#                                                    'mà nhà, đất đó và đối '
#                                                    'tượng được quản lý, sử '
#                                                    'dụng thuộc phạm vi, đối '
#                                                    'tượng quy định tại khoản 1 '
#                                                    'Điều 1, khoản 1 Điều 2 '
#                                                    'Nghị định này thì thực '
#                                                    'hiện sắp xếp lại, xử lý '
#                                                    'theo quy định tại Nghị '
#                                                    'định này.',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'ii__khoản 3_điểm đ',
#                                         'id': ObjectId('69608ff1dd14db83b552d5c6'),
# ...
#                                                    'tra hiện trạng của cơ quan '
#                                                    'có thẩm quyền theo quy '
#                                                    'định tại khoản 1 Điều 6, '
#                                                    'khoản 1 Điều 7 Nghị định '
#                                                    'số 03/2025/NĐ-CP (trong '
#                                                    'trường hợp cơ quan chủ trì '
#                                                    'kiểm tra hiện trạng không '
#                                                    'phải là cơ quan lập phương '
#                                                    'án); Căn cứ khác.. Hôm '
#                                                    'nay, vào hồi ... giờ ngày '
#                                                    '... tháng ... năm ..... '
#                                                    'Thành phần tham gia kiểm '
#                                                    'tra gồm:',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'iv__khoản 2',
#                                         'id': ObjectId('69608ff1dd14db83b552d6aa'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d68f'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 2',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d6ab'): {'content': 'Đại diện cơ quan chủ trì '
#                                                    'kiểm tra - Ông/Bà: Chức '
#                                                    'vụ: Đơn vị:.... - Ông/Bà: '
#                                                    'Chức vụ: ..Đơn vị:.. - '
#                                                    'Ông/Bà: Chức vụ: Đơn '
#                                                    'vị:... án sắp xếp lại, xử '
#                                                    'lý nhà, đất 2. Đại diện cơ '
#                                                    'quan quản lý cấp trên/cơ '
#                                                    'quan có thẩm quyền lập '
#                                                    'phương - Ông/Bà: Chức vụ: '
#                                                    '..Đơn vị:..... - Ông/Bà: '
#                                                    'Chức vụ: - Ông/Bà: Chức '
#                                                    'vụ: Đơn vị:. Đơn vị:....',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'iv__khoản 1',
#                                         'id': ObjectId('69608ff1dd14db83b552d6ab'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d68f'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 1',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d6ac'): {'content': 'Đại diện các cơ quan chức '
#                                                    'năng có liên quan thuộc '
#                                                    'địa phương (nơi có cơ sở '
#                                                    'nhà, đất) - Ông/Bà: - '
#                                                    'Ông/Bà: Chức vụ: Chức vụ: '
#                                                    '.Ɖon vi:...... ..Đơn vị:. '
#                                                    'Đại diện cơ quan chủ trì '
#                                                    'kiểm tra được quy định tại '
#                                                    'khoản 1 Điều 6, khoản 1 '
#                                                    'Điều 7 Nghị định số '
#                                                    '03/2025/NĐ-CP. 2 Cơ quan '
#                                                    'có thẩm quyền lập phương '
#                                                    'án được quy định tại khoản '
#                                                    '3 Điều 4 Nghị định số '
#                                                    '03/2025/NĐ-CP. Đại diện cơ '
#                                                    'quan chức năng có liên '
#                                                    'quan của địa phương bao '
#                                                    'gồm cả đại diện của tổ '
#                                                    'chức có chức năng quản lý, '
#                                                    'kinh doanh nhà của địa '
#                                                    'phương trong trường hợp '
#                                                    'kiểm tra hiện trạng nhà, '
#                                                    'đất tại khoản 1 Điều 16 '
#                                                    'Nghị định số '
#                                                    '03/2025/NĐ-CP. W - Ông/Bà: '
#                                                    'Chức vụ: Đơn vị:..',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'iv__khoản 3',
#                                         'id': ObjectId('69608ff1dd14db83b552d6ac'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d68f'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 3',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d6ad'): {'content': 'Đại diện cơ quan, tổ chức, '
#                                                    'đơn vị quản lý, sử dụng '
#                                                    'nhà, đất - Ông/Bà: Chức '
#                                                    'vụ: ..Đơn vị:... - Ông/Bà: '
#                                                    'Chức vụ: Đơn vị:... - '
#                                                    'Ông/Bà: Chức vụ: ..Đơn '
#                                                    'vị:. ** Cùng tiến hành '
#                                                    'kiểm tra hiện trạng nhà, '
#                                                    'đất tại địa chỉ: I. HỒ SƠ '
#                                                    'PHÁP LÝ VỀ NHÀ, ĐẤT II. '
#                                                    'GIẤY TỜ KHÁC CÓ LIÊN QUAN '
#                                                    'III. KẾT QUẢ KIỂM TRA HIỆN '
#                                                    'TRẠNG NHÀ ĐẤT 1. Chỉ tiêu '
#                                                    'tổng hợp về nhà, đất a) '
#                                                    'Tổng diện tích đất: ...m '
#                                                    'b) Tổng số ngôi nhà: ... '
#                                                    'ngôi c) Tổng diện tích '
#                                                    'nhà: - Tổng diện tích xây '
#                                                    'dựng nhà:.... m - Tổng '
#                                                    'diện tích sàn xây dựng '
#                                                    'nhà: ..m - Tổng diện tích '
#                                                    'sàn sử dụng nhà:..m 2. '
#                                                    'Hiện trạng sử dụng đất - '
#                                                    'Diện tích sử dụng vào mục '
#                                                    'đích chính (diện tích đất '
#                                                    'xây dựng trụ sở làm việc, '
#                                                    'cơ sở hoạt động sự nghiệp, '
#                                                    'bao gồm cả diện tích sân, '
#                                                    'vườn và đường đi nội bộ): '
#                                                    '..m …..m² - Diện tích cho '
#                                                    'mượn: - Diện tích cho '
#                                                    'thuê: ...m - Diện tích đã '
#                                                    'bố trí làm nhà ở: m - Diện '
#                                                    'tích đang bị lấn, chiếm: '
#                                                    '...m - Diện tích sử dụng '
#                                                    'vào mục đích khác (ghi cụ '
#                                                    'thể mục đích sử dụng): ..m '
#                                                    '- Diện tích bỏ trống, chưa '
#                                                    'sử dụng:',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'iv__khoản 4',
#                                         'id': ObjectId('69608ff1dd14db83b552d6ad'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d68f'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 4',
#                                         'type': 'khoản'},
#  ObjectId('69608ff1dd14db83b552d6ae'): {'content': 'Hiện trạng sử dụng nhà '
#                                                    '(m’) m .m² STT Danh mục '
#                                                    'tài sản Số Diện tích | '
#                                                    'Diện tích Diện tích tầng | '
#                                                    'xây dựng sàn xây nhà dựng '
#                                                    'nhà sàn sử dụng nhà Hiện '
#                                                    'trạng | Đối tượng | Ghi '
#                                                    'chú sử dụng sử dụng (1) '
#                                                    '(2) (3) (4) (5) (6) (7) '
#                                                    '(8) (9) | Ngôi 1 Tổng diện '
#                                                    'tích đất tại Mục 2 phải '
#                                                    'bằng điểm a Mục 1 Phần III '
#                                                    '2 Tổng diện tích nhà tại '
#                                                    'các cột (4), (5) và (6) '
#                                                    'phải bằng tổng diện tích '
#                                                    'nhà tương ứng tại điểm c '
#                                                    'Mục 1 Phần III .3 2 |Ngôi '
#                                                    '2... Cộng 4. Hiện trạng '
#                                                    'công trình khác gắn liền '
#                                                    'với đất STT Danh mục tài '
#                                                    'sản Đơn vị tính Số lượng '
#                                                    'Hiện trạng sử dụng Ghi chú '
#                                                    '(1) (2) (3) (4) (5) (6) | '
#                                                    'Tài sản A Tài sản B.... '
#                                                    'Cái/chiếc Cái/chiếc Cộng * '
#                                                    'Ghi chú: - Cơ quan, tổ '
#                                                    'chức, đơn vị quản lý, sử '
#                                                    'dụng nhà, đất chịu trách '
#                                                    'nhiệm về thông tin số liệu '
#                                                    'đã kê khai nêu trên. - '
#                                                    'Thành phần tham gia kiểm '
#                                                    'tra chịu trách nhiệm về '
#                                                    'hiện trạng sử dụng nhà, '
#                                                    'đất tại thời điểm kiểm '
#                                                    'tra. IV. Ý KIẾN CỦA CƠ '
#                                                    'QUAN, TỔ CHỨC, ĐƠN VỊ QUẢN '
#                                                    'LÝ, SỬ DỤNG NHÀ, ĐẤT V. Ý '
#                                                    'KIẾN CỦA CƠ QUAN CHỦ TRÌ '
#                                                    'KIỂM TRA HIỆN TRẠNG VI. Ý '
#                                                    'KIẾN CỦA ĐẠI DIỆN CƠ QUAN '
#                                                    'QUẢN LÝ CẤP TRÊN CƠ QUAN '
#                                                    'CÓ THẨM QUYỀN LẬP PHƯƠNG '
#                                                    'ÁN VII. Ý KIẾN CỦA CÁC CƠ '
#                                                    'QUAN CHỨC NĂNG CỦA ĐỊA '
#                                                    'PHƯƠNG (NƠI CÓ NHÀ, ĐẤT) '
#                                                    'Biên bản được lập vào '
#                                                    'hồi.... giờ... ngày… '
#                                                    'tháng… năm, bao gồm bản có '
#                                                    'giá trị như nhau, mỗi cơ '
#                                                    'quan, tổ chức, đơn vị có '
#                                                    'thành viên tham gia kiểm '
#                                                    'tra giữ 01 bản, 02 bản gửi '
#                                                    'cho cơ quan có thẩm quyền '
#                                                    'lập phương án. ĐẠI DIỆN CƠ '
#                                                    'QUAN QUẢN LÝ CẤP TRÊN/ CƠ '
#                                                    'QUAN CÓ THẦM QUYỀN LẬP '
#                                                    'PHƯƠNG ÁN (Ký, ghi rõ họ '
#                                                    'tên) ĐẠI DIỆN CÁC CƠ QUAN '
#                                                    'CHỨC NĂNG CỦA ĐỊA PHƯƠNG '
#                                                    '(Ký, ghi rõ họ tên) THỦ '
#                                                    'TRƯỞNG CƠ QUAN, TỔ CHỨC, '
#                                                    'ĐƠN VỊ QUẢN LÝ, SỬ DỤNG '
#                                                    'NHÀ, ĐẤT (Ký, ghi rõ họ, '
#                                                    'tên và đóng dấu) ĐẠI DIỆN '
#                                                    'CƠ QUAN CHỦ TRÌ KIẾM TRA '
#                                                    '(Ký, ghi rõ họ tên) * Bao '
#                                                    'gồm cả ý kiến của tổ chức '
#                                                    'có chức năng quản lý, kinh '
#                                                    'doanh nhà của địa phương '
#                                                    'trong trường hợp quy định '
#                                                    'tại khoản 1 Điều 16 Nghị '
#                                                    'định.',
#                                         'full_path': '03/2025/NĐ-CP_chương '
#                                                      'iv__khoản 3',
#                                         'id': ObjectId('69608ff1dd14db83b552d6ae'),
#                                         'is_amendment': False,
#                                         'is_phu_luc': False,
#                                         'parent_id': ObjectId('69608ff1dd14db83b552d68f'),
#                                         'so_hieu': '03/2025/NĐ-CP',
#                                         'title': 'khoản 3',
#                                         'type': 'khoản'}}
