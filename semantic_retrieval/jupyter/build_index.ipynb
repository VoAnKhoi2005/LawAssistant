# %%
from dotenv import load_dotenv
import os

from pymongo import MongoClient

load_dotenv()
uri = os.getenv("MONGODB_URI")
print(uri)
mongo_client = MongoClient(uri)
# Out:
# mongodb+srv://voankhoi_db_user:Khoi05062005%40@kbcluster.yjfhsqp.mongodb.net/

# %%
from semantic_retrieval.src import SearchConfig, HybridSearchEngine
from pymongo import MongoClient
import logging

logging.basicConfig(level=logging.INFO)

config = SearchConfig(
    index_dir="D:/LawAssistant/semantic_retrieval/search_index",
    embedding_batch_size=256,
    processing_batch_size=500,
)

engine = HybridSearchEngine(config)
collection = mongo_client["KB_PROPERTY_LAW"]["law_leaves"]

total_docs = collection.count_documents({})


documents = list(collection.find({}))
# Build từ iterator
engine.build_index(documents)
# Out:
# INFO:semantic_retrieval.src.hybrid_search:Building index for 21,894 documents...
# INFO:semantic_retrieval.src.embedding_service:Loading embedding model: bkai-foundation-models/vietnamese-bi-encoder
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: bkai-foundation-models/vietnamese-bi-encoder
# INFO:semantic_retrieval.src.embedding_service:Model loaded. Embedding dimension: 768
# INFO:semantic_retrieval.src.hybrid_search:Step 1/3: Processing documents...
# INFO:semantic_retrieval.src.hybrid_search:  Processing 1 - 500 / 21,894
# INFO:semantic_retrieval.src.hybrid_search:  Processing 501 - 1,000 / 21,894
# INFO:semantic_retrieval.src.hybrid_search:  Processing 1,001 - 1,500 / 21,894
# INFO:semantic_retrieval.src.hybrid_search:  Processing 1,501 - 2,000 / 21,894
# INFO:semantic_retrieval.src.hybrid_search:  Processing 2,001 - 2,500 / 21,894
# ...

# %%
results = engine.search("Hiện nay ở địa phương tôi đang có kế hoạch thu hồi đất để mở rộng đường giao thông. Tuy nhiên, chưa có thông báo thu hồi và chưa có phương án bồi thường. Nay căn nhà xuống cấp trầm trọng, tôi muốn đập căn nhà cũ đi và xây dựng lại. Xin hỏi nếu sau này thu hồi đất thì tôi có được bồi thường không? Căn cứ pháp lý?", top_k=5)

for result in results:
    print(result.metadata["full_path"])
    print("\n")
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 12.82it/s]
# 31/2024/QH15_chương xvi_mục 2_điều 254_khoản 2
#
#
# 31/2024/QH15_chương vii_mục 2_điều 101_khoản 2
#
#
# 31/2024/QH15_chương vii_mục 1_điều 92_khoản 3_điểm a
#
#
# 31/2024/QH15_chương xvi_mục 2_điều 254_khoản 1
#
#
# 31/2024/QH15_chương vii_mục 2_điều 101_khoản 1
